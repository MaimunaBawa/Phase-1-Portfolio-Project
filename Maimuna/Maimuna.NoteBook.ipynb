# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os


df= pd.read_csv("../csv/nyc_all_parks_filtered.csv")

# %%
#looking at min and max of attendance by category

# %%
#looking at mean, median,mode of attendance by category

# %%
sorted_df = df.sort_values(by="attendance", ascending= False)

plt.figure(figsize=(10,6))

# swap out attendents and and use count of event_type as y-axis
'''
#sns.barplot(data=sorted_df,x ="borough", y ="attendance",palette="viridis")
plt.xticks(rotation=45)  # Rotate x-axis labels if needed
plt.title("Events Across Different Boroughs")
plt.xlabel("Borough")
plt.ylabel("attendance")
plt.show()'''
# Out:
# /var/folders/rg/csr6nvbs3kn2m8d77jr48cqw0000gn/T/ipykernel_6018/2412791461.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=sorted_df,x ="borough", y ="attendance",palette="viridis")
