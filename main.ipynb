# %%
import requests
import pandas as pd
import json
import os

# %%
url = "https://data.cityofnewyork.us/resource/6v4b-5gp4.json"
page = requests.get(url)
converted = page.json()

# Pull your JSON data programmatically into your Python program, a
# and save this object into the path data/json.
# Parameters for the API request (limit the number of records per request)
params = {
    '$limit': 50000,  # Max limit per request
}

# Function to fetch all data with pagination
def fetch_all_data():
    all_data = []  # List to store all records
    offset = 0  # Starting point (offset)

    while True:
        # Add the current offset to the parameters
        params['$offset'] = offset

        # Send the request to the API
        response = requests.get(url, params=params)

        if response.status_code == 200:
            data = response.json()

            # If there is no data in the response, stop the loop
            if not data:
                break

            # Append the data to the all_data list
            all_data.extend(data)

            # Print progress (optional, for debugging)
            print(f"Fetched {len(data)} records, Total: {len(all_data)}")

            # Increase the offset by the limit for the next page
            offset += 50000
        else:
            print(f"Error fetching data: {response.status_code}")
            break

    return all_data

# Fetch all data with pagination
all_data = fetch_all_data()

# Convert the data into a pandas DataFrame
df = pd.DataFrame(all_data)


data_folder_csv = 'csv'
os.makedirs(data_folder_csv, exist_ok=True)  # Ensure the folder exists
csv_path = os.path.join(data_folder_csv, 'nyc_all_parks_special_event.csv')

# Save the DataFrame to a CSV file in the 'data/csv' folder
df.to_csv(csv_path, index=False)
# Out:
# Fetched 18802 records, Total: 18802

# %%
df.columns
# Out:
# Index(['unit', 'group_name_partner', 'date_and_time', 'borough',
#        'locationtype', 'location', 'event_name', 'event_type', 'category',
#        'attendance', 'audience', 'source', 'classification'],
#       dtype='object')

# %%
#df.head()
### dropping unwanted columns 
to_drop = ["event_name","source","group_name_partner","unit","locationtype"]
df = df.drop(to_drop, axis=1)



#Converting our time 

df['date_and_time'] = pd.to_datetime(df['date_and_time'])

df['date'] = df['date_and_time'].dt.date
df['time'] = df['date_and_time'].dt.time

#dropping date_and_time columns as we separated these into 2 columns 
df = df.drop("date_and_time" ,  axis = 1)

df = df.sort_values(by= 'date')
df = df.set_index('date')

data_folder_csv = 'csv'
os.makedirs(data_folder_csv, exist_ok=True)  # Ensure the folder exists
csv_path = os.path.join(data_folder_csv, 'nyc_all_parks_filtered.csv')

# Save the DataFrame to a CSV file in the 'data/csv' folder
df.to_csv(csv_path, index= True)

df.head(14)
# Out:
#               borough                                  location  \
# date
# 2002-06-25  Manhattan            Pelham Fritz Recreation Center
# 2002-06-25  Manhattan  Constance Baker Motley Recreation Center
# 2002-06-29  Manhattan                                White Park
# 2002-06-30  Manhattan                   Bloomingdale Playground
# 2002-07-02  Manhattan                Abraham Lincoln Playground
# 2017-01-06      Bronx              Owen Dolen Recreation Center
# 2017-01-06      Bronx              Owen Dolen Recreation Center
# 2017-01-13      Bronx              Owen Dolen Recreation Center
# 2017-01-13      Bronx              Owen Dolen Recreation Center
# 2017-01-14   Brooklyn                Red Hook Recreation Center
# 2017-01-14   Brooklyn                Red Hook Recreation Center
# 2017-01-28      Bronx              St. Mary's Recreation Center
# 2017-01-28      Bronx              St. Mary's Recreation Center
# 2017-02-04      Bronx              West Bronx Recreation Center
#
#                         event_type      category attendance  \
# date
# 2002-06-25             Local Event  Arts/Culture       55.0
# 2002-06-25   Community Based Event  Arts/Culture       22.0
# 2002-06-29             Local Event   Mobile Unit      200.0
# 2002-06-30             Local Event   Mobile Unit      125.0
# 2002-07-02             Local Event   Mobile Unit      105.0
# 2017-01-06             Local Event  Arts/Culture       50.0
# 2017-01-06             Local Event  Arts/Culture       50.0
# 2017-01-13             Local Event  Arts/Culture       21.0
# 2017-01-13             Local Event  Arts/Culture       21.0
# 2017-01-14  Tournament/Competition         Sport        NaN
# 2017-01-14  Tournament/Competition         Sport        NaN
# 2017-01-28             Local Event  Arts/Culture       12.0
# 2017-01-28             Local Event  Arts/Culture       12.0
# 2017-02-04             Local Event  Arts/Culture       15.0
#
#                                                      audience classification  \
# date
# 2002-06-25  Children, Young Adult, Adults, Teens, Adaptive...            NaN
# 2002-06-25  Children, Young Adult, Adults, Teens, Seniors,...            NaN
# 2002-06-29  Children, Young Adult, Adults, Teens, Adaptive...            NaN
# 2002-06-30  Tot, Young Adult, Children, Adults, Teens, Ada...            NaN
# 2002-07-02  Young Adult, Adults, Teens, Adaptive, General ...            NaN
# 2017-01-06               Teens;#Young Adult;#Adults;#Children           Play
# 2017-01-06               Teens, Young Adult, Adults, Children           Play
# 2017-01-13                                           Children           Play
# 2017-01-13                                           Children           Play
# 2017-01-14                                 Teens;#Young Adult         Tier 1
# 2017-01-14                                 Teens, Young Adult         Tier 1
# 2017-01-28                                     General Public           AC&F
# 2017-01-28                                     General Public           AC&F
# 2017-02-04                       Teens, Young Adult, Children           Play
#
#                 time
# date
# 2002-06-25  16:30:00
# 2002-06-25  17:00:00
# 2002-06-29  00:30:00
# 2002-06-30  00:30:00
# 2002-07-02  00:30:00
# 2017-01-06  10:00:00
# 2017-01-06  15:00:00
# 2017-01-13  10:00:00
# 2017-01-13  15:00:00
# 2017-01-14  13:00:00
# 2017-01-14  18:00:00
# 2017-01-28  18:00:00
# 2017-01-28  23:00:00
# 2017-02-04  15:00:00

# %%
#df = df.groupby('audience').filter(lambda x: len(x) > 123)

df.head(14)
# Out:
#               borough                                  location  \
# date
# 2002-06-25  Manhattan            Pelham Fritz Recreation Center
# 2002-06-25  Manhattan  Constance Baker Motley Recreation Center
# 2002-06-29  Manhattan                                White Park
# 2002-06-30  Manhattan                   Bloomingdale Playground
# 2002-07-02  Manhattan                Abraham Lincoln Playground
# 2017-01-06      Bronx              Owen Dolen Recreation Center
# 2017-01-06      Bronx              Owen Dolen Recreation Center
# 2017-01-13      Bronx              Owen Dolen Recreation Center
# 2017-01-13      Bronx              Owen Dolen Recreation Center
# 2017-01-14   Brooklyn                Red Hook Recreation Center
# 2017-01-14   Brooklyn                Red Hook Recreation Center
# 2017-01-28      Bronx              St. Mary's Recreation Center
# 2017-01-28      Bronx              St. Mary's Recreation Center
# 2017-02-04      Bronx              West Bronx Recreation Center
#
#                         event_type      category attendance  \
# date
# 2002-06-25             Local Event  Arts/Culture       55.0
# 2002-06-25   Community Based Event  Arts/Culture       22.0
# 2002-06-29             Local Event   Mobile Unit      200.0
# 2002-06-30             Local Event   Mobile Unit      125.0
# 2002-07-02             Local Event   Mobile Unit      105.0
# 2017-01-06             Local Event  Arts/Culture       50.0
# 2017-01-06             Local Event  Arts/Culture       50.0
# 2017-01-13             Local Event  Arts/Culture       21.0
# 2017-01-13             Local Event  Arts/Culture       21.0
# 2017-01-14  Tournament/Competition         Sport        NaN
# 2017-01-14  Tournament/Competition         Sport        NaN
# 2017-01-28             Local Event  Arts/Culture       12.0
# 2017-01-28             Local Event  Arts/Culture       12.0
# 2017-02-04             Local Event  Arts/Culture       15.0
#
#                                                      audience classification  \
# date
# 2002-06-25  Children, Young Adult, Adults, Teens, Adaptive...            NaN
# 2002-06-25  Children, Young Adult, Adults, Teens, Seniors,...            NaN
# 2002-06-29  Children, Young Adult, Adults, Teens, Adaptive...            NaN
# 2002-06-30  Tot, Young Adult, Children, Adults, Teens, Ada...            NaN
# 2002-07-02  Young Adult, Adults, Teens, Adaptive, General ...            NaN
# 2017-01-06               Teens;#Young Adult;#Adults;#Children           Play
# 2017-01-06               Teens, Young Adult, Adults, Children           Play
# 2017-01-13                                           Children           Play
# 2017-01-13                                           Children           Play
# 2017-01-14                                 Teens;#Young Adult         Tier 1
# 2017-01-14                                 Teens, Young Adult         Tier 1
# 2017-01-28                                     General Public           AC&F
# 2017-01-28                                     General Public           AC&F
# 2017-02-04                       Teens, Young Adult, Children           Play
#
#                 time
# date
# 2002-06-25  16:30:00
# 2002-06-25  17:00:00
# 2002-06-29  00:30:00
# 2002-06-30  00:30:00
# 2002-07-02  00:30:00
# 2017-01-06  10:00:00
# 2017-01-06  15:00:00
# 2017-01-13  10:00:00
# 2017-01-13  15:00:00
# 2017-01-14  13:00:00
# 2017-01-14  18:00:00
# 2017-01-28  18:00:00
# 2017-01-28  23:00:00
# 2017-02-04  15:00:00
