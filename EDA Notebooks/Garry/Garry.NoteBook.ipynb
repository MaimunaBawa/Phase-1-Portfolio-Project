# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns 
import numpy as np

df = pd.read_csv('../../csv/nyc_all_parks_filtered.csv')

# %%
#For my EDA i have taken out of all the none values which bring my dataset amount to 10249 rows x 10 Columns 
data_cleaned
# Out:
#             date        borough  \
# 5     2017-01-06          Bronx
# 6     2017-01-06          Bronx
# 7     2017-01-13          Bronx
# 8     2017-01-13          Bronx
# 11    2017-01-28          Bronx
# ...          ...            ...
# 18182 2024-08-21          Bronx
# 18425 2024-09-21  Staten Island
# 18521 2024-10-10      Manhattan
# 18588 2024-10-19       Brooklyn
# 18592 2024-10-23          Bronx
#
#                                                 location  \
# 5                           Owen Dolen Recreation Center
# 6                           Owen Dolen Recreation Center
# 7                           Owen Dolen Recreation Center
# 8                           Owen Dolen Recreation Center
# 11                          St. Mary's Recreation Center
# ...                                                  ...
# 18182                           Williamsbridge Oval Park
# 18425  Franklin D. Roosevelt Boardwalk and Beach, Sou...
# 18521                          Inwood Hill Nature Center
# 18588                             Hendrick I. Lott House
# 18592                        Playground for All Children
#
#                    event_type                     category  attendance  \
# 5                 Local Event                 Arts/Culture        50.0
# 6                 Local Event                 Arts/Culture        50.0
# 7                 Local Event                 Arts/Culture        21.0
# 8                 Local Event                 Arts/Culture        21.0
# 11                Local Event                 Arts/Culture        12.0
# ...                       ...                          ...         ...
# 18182   Community Based Event                        Sport       501.0
# 18425  Tournament/Competition                        Sport        60.0
# 18521   Community Based Event                 Arts/Culture        24.0
# 18588   Community Based Event              Family Festival        80.0
# 18592   Agency Produced Event  Academic/Out of School time       170.0
#
#                                    audience classification      time  year
# 5      Teens, Young Adult, Adults, Children           Play  15:00:00  2017
# 6      Teens;#Young Adult;#Adults;#Children           Play  10:00:00  2017
# 7                                  Children           Play  10:00:00  2017
# 8                                  Children           Play  15:00:00  2017
# 11                           General Public           AC&F  23:00:00  2017
# ...                                     ...            ...       ...   ...
# 18182       Children, Teens, General Public         Tier 1  15:00:00  2024
# 18425          Young Adult, Adults, Seniors         Tier 3  12:30:00  2024
# 18521                   Young Adult, Adults         Awards  16:00:00  2024
# 18588                        General Public           Play  16:00:00  2024
# 18592                              Children           Play  14:00:00  2024
#
# [10249 rows x 10 columns]

# %%
#Cleaning out null values 
data_cleaned = df.dropna()

# %%
#How Many nulls are in each column after dropping null values [filtered csv ]
data_cleaned.isna().sum()
# Out:
# date              0
# borough           0
# location          0
# event_type        0
# category          0
# attendance        0
# audience          0
# classification    0
# time              0
# dtype: int64

# %%
plt.figure(figsize=(22, 20))
sns.barplot(data= data_cleaned, x='classification' , y = 'attendance' , errorbar = None, color= 'red')
plt.title('Attendance  Per Classification')
plt.xticks(rotation=45)
plt.show()

# %%
#Attendance per Classification 
#How many people attended specific events that fell under a certain Classification? 

"""
After cleaning my data we can see that one of the popular events that people attended throughout the city were music events. Other popular events included dance, 
movues , and plays as well. Some of the least popular events were academics and summer 2020. Summer 2020 was around coivd so that would be 
the reason for the low attendance. 

"""
# Out:
# '\nAfter cleaning my data we can see that one of the popular events that people attended throughout the city were music events. Other popular events included dance, \nmovues , and plays as well. Some of the least popular events were academics and summer 2020. Summer 2020 was around coivd so that would be \nthe reason for the low attendance. \n\n'

# %%
plt.figure(figsize=(20, 20))
sns.barplot(data=data_cleaned, x='borough' , y = 'attendance', hue = 'event_type', errorbar= None )
plt.title('Attendance Per Borough w/ Event Type')
plt.xlabel('Borough')
plt.ylabel('attendance')
plt.xticks(rotation=45)
plt.show()

# %%
# What are the most popular events within each Borough? 

"""
 So as you see the graph above Tournament/Competition event types are the most popular in Queens, Staten Island and
 the Bronx. Staten Island has a big outlier for competition as there was a track and field event, where over 2000 people attended. 
 But overall looking at all the boroughs outide of manhattan, Tournament/Competiton seems to be the most popular 
 event. Manhattan and Brooklyn enjoyed community based events.  The least popular event in every borough (except queens) was open house events. 

"""
# Out:
# '\n So as you see the graph above Tournament/Competition event types are the most popular in Queens, Staten Island and\n the Bronx. Staten Island has a big outlier for competition as there was a track and field event, where over 2000 people attended. \n But overall looking at all the boroughs outide of manhattan, Tournament/Competiton seems to be the most popular \n event. Manhattan and Brooklyn enjoyed community based events.  The least popular event in every borough (except queens) was open house events. \n\n'

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=data_cleaned, x='borough' , y = 'attendance', hue = 'category' , errorbar= None)
plt.title('Attendance Per Borough w/ Category')
plt.xlabel('Borough')
plt.ylabel('attendance')
plt.xticks(rotation=45)
plt.show()

# %%
#Average attendance per Borough w/ Category
# What are the popular events via Category to people attend viewing each Borough? 

"""
This graph shows more specifically the events people attended in each borough showing the category, rather than the event type. With 
category is more descriptive in terms of what exactly the events people attended. Besides Staten Island , Family Festival was the most popular category 
througout NYC. A lot of people when to performances in Quenns and Manhattan. 
"""
# Out:
# '\nThis graph shows more specifically the events people attended in each borough showing the category, rather than the event type. With \ncategory is more descriptive in terms of what exactly the events people attended. Besides Staten Island , Family Festival was a popular category \nthrougout NYC. A lot of people when to performances in Quenns and Manhattan. \n'

# %%
plt.figure(figsize=(20, 10))
sns.barplot(data=data_cleaned, x='category' , y = 'attendance', errorbar= None , color= 'orange' )
plt.title('Attendance Per Category')
plt.xticks(rotation=60)
plt.show()

# %%
#Average Attandance per Category 

"""
This graph is overall Attendance per Category throughout NYC. and we see here that Performance and Family Festival were great standouts. 
Nature and Fitness being the least 2 popular. 




"""
# Out:
# '\nThis graph is overally Attendance per Category throughout NYC. and we see here that Perfoce and Family Festival were great standouts. Nature and Fitness\nbeing the least 2 popular. \n\n\n\n\n'

# %%
data_cleaned['date'] = pd.to_datetime(data_cleaned['date'])


# Extract the year from the 'date' column
data_cleaned['year'] = data_cleaned['date'].dt.year

#plt.figure(figsize=(20, 10))
sns.lineplot(data= data_cleaned, x='year' , y = 'attendance', hue = 'borough', errorbar= None, marker = 'o')
plt.title('Attendance Per Borough throughout the years')
plt.xlabel('Year')
plt.ylabel('attendance')
plt.xticks(rotation=45)
plt.show()
# Out:
# /var/folders/w7/jd1z45j96837md4q7byfwykm0000gn/T/ipykernel_46231/4022728555.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_cleaned['date'] = pd.to_datetime(data_cleaned['date'])
# /var/folders/w7/jd1z45j96837md4q7byfwykm0000gn/T/ipykernel_46231/4022728555.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_cleaned['year'] = data_cleaned['date'].dt.year

# %%
#Attendance per borough thoughout the Years 

"""
Attendance through out there years here we see a decline leading into the year 2020 for all Boroughs as this would have been due to Covid. Once we past that 
each Borough shows increase up till 2021 or 2022, there is some drop down but Queens has the biggest increast in attandance post-Covid. 
Queens attendance did drop after 2023 but it was still significantly higher than all the remaining Boroughs.After 2023 it seems like Brooklyn 
had the second highest attendance. Overall the Bronx had the lowest attendnace throughout this whole time  but did have an increase after 2023. 


"""
# Out:
# '\nAttendance through out there years here we see a decline leading into the year 2020 for all Boroughs as this would have been due to Covid. Once we past that \neach Borough shows increase up till 2021 or 2022, there is some drop down but Queens has the biggest increast in attandance post-Covid. \nQueens attendance did drop after 2023 but it was still significantly higher than all the remaining Boroughs.After 2023 it seems like Brooklyn \nhad the second highest attendance. Overall the Bronx had the lowest attendnace throughout this whole time  but did have an increase after 2023. \n\n\n'
